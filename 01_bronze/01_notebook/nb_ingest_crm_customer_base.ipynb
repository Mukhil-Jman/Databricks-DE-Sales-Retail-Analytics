# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('MP-DE').getOrCreate()

# %%
df = spark.read.option("header", "true").csv('/Volumes/cl_mp_de/01_bronze/01_raw_excel_data/CRM_CUST_BASE_RAW.csv')
display(df)

# %%
df.write.format('delta').option("delta.columnMapping.mode", "name").mode("overwrite").saveAsTable("cl_mp_de.01_bronze.bronze_crm_customer_base")
