-- %%
DROP TABLE IF EXISTS cl_mp_de.`03_gold_dim`.dim_customer

-- %%
CREATE TABLE cl_mp_de.`03_gold_dim`.dim_customer (
    customer_key BIGINT GENERATED ALWAYS AS IDENTITY,
    customer_id VARCHAR(10),
    full_name VARCHAR(255),
    contact_information VARCHAR(10),
    gender VARCHAR(5),
    joined_date DATE
)

-- %%
INSERT INTO cl_mp_de.`03_gold_dim`.dim_customer (
  customer_id,
  full_name,
  contact_information,
  gender,
  joined_date
)
SELECT
  customer_id,
  full_name,
  contact_information,
  gender,
  joined_date
FROM cl_mp_de.`02_silver`.silver_customer;

-- %%
select * from cl_mp_de.`03_gold_dim`.dim_customer;
