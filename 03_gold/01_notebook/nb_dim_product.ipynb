-- %%
DROP TABLE IF EXISTs cl_mp_de.`03_gold_dim`.dim_product

-- %%
CREATE TABLE cl_mp_de.`03_gold_dim`.dim_product (
  product_key BIGINT GENERATED ALWAYS AS IDENTITY,
  product_id VARCHAR(10),
  item_name  VARCHAR(255),
  category_type VARCHAR(255),
  base_cost     DECIMAL(10,2),
  marked_price DECIMAL(10,2)
)

-- %%
INSERT INTO cl_mp_de.`03_gold_dim`.dim_product (
  product_id,
  item_name,
  category_type,
  base_cost,
  marked_price
)
SELECT * FROM cl_mp_de.`02_silver`.silver_product;

-- %%
SELECT * FROM cl_mp_de.`03_gold_dim`.dim_product
