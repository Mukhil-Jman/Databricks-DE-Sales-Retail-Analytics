-- %%
CREATE TABLE cl_mp_de.`03_gold_dim`.dim_reason (
  reason_key BIGINT GENERATED ALWAYS AS IDENTITY,
  rsn_code VARCHAR(255)
)

-- %%
INSERT INTO cl_mp_de.`03_gold_dim`.dim_reason (rsn_code)
SELECT DISTINCT(rsn_code) FROM cl_mp_de.`02_silver`.silver_return_transaction_logs

-- %%
SELECT * FROM cl_mp_de.`03_gold_dim`.dim_reason;

-- %%
SELECT * FROM cl_mp_de.`02_silver`.silver_return_transaction_logs;
