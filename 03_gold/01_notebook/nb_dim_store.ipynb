-- %%
DROP TABLE IF EXISTS cl_mp_de.`03_gold_dim`.dim_store

-- %%
CREATE TABLE cl_mp_de.`03_gold_dim`.dim_store (
  store_key BIGINT GENERATED ALWAYS AS IDENTITY,
  store_id VARCHAR(10),
  location_name_and_address VARCHAR(255),
  city_and_region VARCHAR(255),
  manager_contact VARCHAR(20)
)

-- %%
INSERT INTO cl_mp_de.`03_gold_dim`.dim_store (
  store_id,
  location_name_and_address,
  city_and_region,
  manager_contact
)
SELECT * FROM cl_mp_de.`02_silver`.silver_stores_geolocation_list

-- %%
SELECT * FROM cl_mp_de.`03_gold_dim`.dim_store
