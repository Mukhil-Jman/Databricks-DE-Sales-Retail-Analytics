# %%
gold_dim_customer = dbutils.notebook.run("/Workspace/ws_mp_de_tn/03_gold/01_notebook/nb_dim_customer", 300)

# %%
gold_dim_product = dbutils.notebook.run("/Workspace/ws_mp_de_tn/03_gold/01_notebook/nb_dim_product", 300)

# %%
gold_dim_store = dbutils.notebook.run("/Workspace/ws_mp_de_tn/03_gold/01_notebook/nb_dim_store", 300)

# %%
gold_dim_date = dbutils.notebook.run("/Workspace/ws_mp_de_tn/03_gold/01_notebook/nb_dim_date", 300)

# %%
gold_fact_retail_analytics = dbutils.notebook.run("/Workspace/ws_mp_de_tn/03_gold/01_notebook/nb_fact_sales_analytics", 300)
