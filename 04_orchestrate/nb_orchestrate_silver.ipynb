# %%
silver_crm_customer_base = dbutils.notebook.run("/Workspace/ws_mp_de_tn/02_silver/01_notebook/nb_trns_crm_customer_base", 300)

# %%
silver_inventory_levels = dbutils.notebook.run("/Workspace/ws_mp_de_tn/02_silver/01_notebook/nb_trns_inventory_levels", 300)

# %%
silver_mst_product_master = dbutils.notebook.run("/Workspace/ws_mp_de_tn/02_silver/01_notebook/nb_trns_mst_product_master", 300)

# %%
silver_return_transaction_logs = dbutils.notebook.run("/Workspace/ws_mp_de_tn/02_silver/01_notebook/nb_trns_return_transaction_logs", 300)

# %%
silver_sales = dbutils.notebook.run("/Workspace/ws_mp_de_tn/02_silver/01_notebook/nb_trns_sales", 300)

# %%
silver_store_geolocation = dbutils.notebook.run("/Workspace/ws_mp_de_tn/02_silver/01_notebook/nb_trns_store_geolocation", 300)
